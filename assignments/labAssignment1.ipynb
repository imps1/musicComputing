# %% [markdown]
# <a href="https://colab.research.google.com/github/imps1/musicComputing/blob/main/assignments/labAssignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries

import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display


# !git clone https://github.com/jcdevaney/musicComputing2026.git
# Out:
# fatal: destination path 'musicComputing2026' already exists and is not an empty directory.

# %%
def printTextNum(string,number):
    print(string)
    print(number)

# %%
#open file and define sample rate
file = '/content/musicComputing2026/audioFiles/avm.wav'
samplingRate = 44100
plotAudio=(file,samplingRate)

sig, sr = librosa.load(file,mono=True,sr=samplingRate)

printTextNum('avm.wav',44100)


plt.plot(.25)

time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

excursion=max(abs(sig))
sigNew = (sig/excursion)
plt.plot(time,sigNew)


plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# avm.wav
# 44100
# Text(0, 0.5, 'Amplitude')

# %%
file = '/content/musicComputing2026/audioFiles/avm.wav'
samplingRate = 441

sig, sr = librosa.load(file,mono=True,sr=samplingRate)

printTextNum('avm.wav',441)


plt.plot(.25)

time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

excursion=max(abs(sig))
sigNew = (sig/excursion)
plt.plot(time,sigNew)

plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# avm.wav
# 441
# Text(0, 0.5, 'Amplitude')
