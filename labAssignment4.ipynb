# %% [markdown]
# <a href="https://colab.research.google.com/github/imps1/musicComputing/blob/main/labAssignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

# %%
def plotAudio2(sig,sampleRate,title):
  time=np.arange(0,sig.shape[0])/sampleRate

  excursion=max(abs(sig))
  sigNew = sig / excursion

  xlabel = 'Time (seconds)'
  ylabel = 'Amplitude'

  plt.plot(time,sigNew)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.title(title)
  plt.show()

  sig , sr = librosa.load('musicComputing2026/audioFiles/avm.wav')

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):


    spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)), ref=np.max)

    librosa.display.specshow(spec, y_axis=specType)
    plt.colorbar(format='%+2.0f dB')
    plt.title({specType}, waveType)
    plt.show()

    sig , sr = librosa.load('musicComputing2026/audioFiles/avm.wav')

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):


    plotAudio2(sig,sr,title)

    plotAudioFreqDomain(sig,sr,title,winSize,specType)

# %%
def additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent):

    harmonics = np.arange(1,numHarmonics+1,seqHarm)
    harmonics = harmonics[1:-1]

    timeSeries = np.linspace(0, 1, samplingRate)


    signal = np.cos(2.0 * np.pi * frequency * timeSeries)


    for harm in harmonics:
        signal = signal + np.cos(2.0 * np.pi * frequency * harm * timeSeries)/harm**ampExponent

    excursion=max(abs(signal))
    signal = signal / excursion


    plt.plot(timeSeries,signal)
    plt.xlabel('Time (Sec)')
    plt.ylabel('Amplitude')
    plt.title(waveType)
    plt.plot

    return signal

# %%
def makeWaveform(frequency,samplingRate,numHarmonics,waveType):


  if waveType == 'sawtooth':
      seqHarm = 1
      ampExponent = 1
  elif waveType == 'square':
      seqHarm = 2
      ampExponent = 1
  elif waveType == 'triangle':
      seqHarm = 2
      ampExponent = 2
  else: 'sine'
  numHarmonics = 1
  seqHarm = 1
  ampExponent = 1

  additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)

# %%
def visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType):


  sig = makeWaveform(frequency,samplingRate,numHarmonics,waveType)


  plotAudio2(sig,samplingRate,waveType)

  plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)


  return sig

# %%
# 7

makeWaveform(frequency,samplingRate,numHarmonics,waveType)


frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sine'
winSize = 1024
specType = 'log'



signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(data=visualizeWaveforms, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_190/517278651.py in <cell line: 0>()
#      13
#      14
# ---> 15 signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      16 IPython.display.Audio(data=visualizeWaveforms, rate=samplingRate)
#      17
#
# /tmp/ipykernel_190/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       5
#       6
# ----> 7   plotAudio2(sig,samplingRate,waveType)
#       8
#       9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#
# /tmp/ipykernel_190/3112494706.py in plotAudio2(sig, sampleRate, title)
#       1 def plotAudio2(sig,sampleRate,title):
# ----> 2   time=np.arange(0,sig.shape[0])/sampleRate
#       3
#       4   excursion=max(abs(sig))
#       5   sigNew = sig / excursion
#
# ...

# %%
# 8
makeWaveform(frequency,samplingRate,numHarmonics,waveType)

frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sawtooth'
winSize = 1024
specType = 'log'


signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(data=signal, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_190/1209746030.py in <cell line: 0>()
#      10
#      11
# ---> 12 signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      13 IPython.display.Audio(data=signal, rate=samplingRate)
#
# /tmp/ipykernel_190/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       5
#       6
# ----> 7   plotAudio2(sig,samplingRate,waveType)
#       8
#       9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#
# /tmp/ipykernel_190/3112494706.py in plotAudio2(sig, sampleRate, title)
#       1 def plotAudio2(sig,sampleRate,title):
# ----> 2   time=np.arange(0,sig.shape[0])/sampleRate
#       3
#       4   excursion=max(abs(sig))
#       5   sigNew = sig / excursion
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# 9
makeWaveform(frequency,samplingRate,numHarmonics,waveType)

frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'triangle'
winSize = 1024
specType = 'log'


signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(data=signal, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_190/1382757469.py in <cell line: 0>()
#      10
#      11
# ---> 12 signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      13 IPython.display.Audio(data=signal, rate=samplingRate)
#
# /tmp/ipykernel_190/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       5
#       6
# ----> 7   plotAudio2(sig,samplingRate,waveType)
#       8
#       9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#
# /tmp/ipykernel_190/3112494706.py in plotAudio2(sig, sampleRate, title)
#       1 def plotAudio2(sig,sampleRate,title):
# ----> 2   time=np.arange(0,sig.shape[0])/sampleRate
#       3
#       4   excursion=max(abs(sig))
#       5   sigNew = sig / excursion
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
# 10
makeWaveform(frequency,samplingRate,numHarmonics,waveType)

frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'square'
winSize = 1024
specType = 'log'

signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(data=signal, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_190/2451616220.py in <cell line: 0>()
#       9 specType = 'log'
#      10
# ---> 11 signal = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      12 IPython.display.Audio(data=signal, rate=samplingRate)
#
# /tmp/ipykernel_190/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       5
#       6
# ----> 7   plotAudio2(sig,samplingRate,waveType)
#       8
#       9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#
# /tmp/ipykernel_190/3112494706.py in plotAudio2(sig, sampleRate, title)
#       1 def plotAudio2(sig,sampleRate,title):
# ----> 2   time=np.arange(0,sig.shape[0])/sampleRate
#       3
#       4   excursion=max(abs(sig))
#       5   sigNew = sig / excursion
#
# ...
