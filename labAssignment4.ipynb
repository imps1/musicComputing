# %% [markdown]
# <a href="https://colab.research.google.com/github/imps1/musicComputing/blob/main/labAssignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa.display
import IPython.display
import librosa

# %%
def plotAudio2(sig,sampleRate,title):
  time=np.arange(0,sig.shape[0])/sampleRate

  excursion=max(abs(sig))
  sigNew = sig / excursion

  xlabel = 'Time (seconds)'
  ylabel = 'Amplitude'

  plt.plot(time,sigNew)
  plt.xlabel(xlabel)
  plt.ylabel(ylabel)
  plt.title(title)
  plt.show()

# %%
def plotAudioFreqDomain(sig,sr,title,winSize,specType):


    spec = librosa.amplitude_to_db(np.abs(librosa.stft(sig,n_fft=winSize)), ref=np.max)

    librosa.display.specshow(spec, y_axis=specType)
    plt.colorbar(format='%+2.0f dB')
    plt.title({specType}, waveType)
    plt.show()

# %%
def plotAudioFunc(sig,sr,title,winSize,specType):


    plotAudio2(sig,sr,title)

    plotAudioFreqDomain(sig,sr,title,winSize,specType)

# %%
def additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent):

    harmonics = np.arange(1,numHarmonics+1,seqHarm)
    harmonics = harmonics[1:-1]

    timeSeries = np.linspace(0, 1, samplingRate)


    signal = np.cos(2.0 * np.pi * frequency * timeSeries)


    for harm in harmonics:
        signal = signal + np.cos(2.0 * np.pi * frequency * harm * timeSeries)/harm**ampExponent

    excursion=max(abs(signal))
    signal = signal / excursion


    plt.plot(timeSeries,signal)
    plt.xlabel('Time (Sec)')
    plt.ylabel('Amplitude')
    plt.title(waveType)
    plt.plot

    return signal

# %%
def makeWaveform(frequency,samplingRate,numHarmonics,waveType):


  if waveType == 'sawtooth':
      seqHarm = 1
      ampExponent = 1
  elif waveType == 'square':
      seqHarm = 2
      ampExponent = 1
  elif waveType == 'triangle':
      seqHarm = 2
      ampExponent = 2
  else: 'sine'
  numHarmonics = 1
  seqHarm = 1
  ampExponent = 1

  signal = additiveSynthesis(samplingRate,frequency,numHarmonics,seqHarm,ampExponent)

  return signal

# %%
def visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType):


  sig = makeWaveform(frequency,samplingRate,numHarmonics,waveType)


  plotAudio2(sig,samplingRate,waveType)

  plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)


  return sig

# %%
# 7

frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sine'
winSize = 1024
specType = 'log'



sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(sig, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_298/115985620.py in <cell line: 0>()
#      10
#      11
# ---> 12 sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      13 IPython.display.Audio(sig, rate=samplingRate)
#
# /tmp/ipykernel_298/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       7   plotAudio2(sig,samplingRate,waveType)
#       8
# ----> 9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#      10
#      11
#
# /tmp/ipykernel_298/3510600926.py in plotAudioFreqDomain(sig, sr, title, winSize, specType)
#       6     librosa.display.specshow(spec, y_axis=specType)
#       7     plt.colorbar(format='%+2.0f dB')
# ----> 8     plt.title({specType}, waveType)
#       9     plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    4383     **kwargs,
#    4384 ) -> Text:
# -> 4385     return gca().set_title(label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    4386
#    4387
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     198         title.update(default)
#     199         if fontdict is not None:
# --> 200             title.update(fontdict)
#     201         title._internal_update(kwargs)
#     202         return title
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/text.py in update(self, kwargs)
#     195         # docstring inherited
#     196         ret = []
# --> 197         kwargs = cbook.normalize_kwargs(kwargs, Text)
#     198         sentinel = object()  # bbox can be None, so use another sentinel.
#     199         # Update fontproperties first, as it has lowest priority.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in normalize_kwargs(kw, alias_mapping)
#    1785     ret = {}  # output dictionary
#    1786
# -> 1787     for k, v in kw.items():
#    1788         canonical = to_canonical.get(k, k)
#    1789         if canonical in canonical_to_seen:
#
# AttributeError: 'str' object has no attribute 'items'

# %%
# 8

frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'sawtooth'
winSize = 1024
specType = 'log'


sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(sig, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_298/1641469672.py in <cell line: 0>()
#       9
#      10
# ---> 11 sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      12 IPython.display.Audio(sig, rate=samplingRate)
#
# /tmp/ipykernel_298/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       7   plotAudio2(sig,samplingRate,waveType)
#       8
# ----> 9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#      10
#      11
#
# /tmp/ipykernel_298/3510600926.py in plotAudioFreqDomain(sig, sr, title, winSize, specType)
#       6     librosa.display.specshow(spec, y_axis=specType)
#       7     plt.colorbar(format='%+2.0f dB')
# ----> 8     plt.title({specType}, waveType)
#       9     plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    4383     **kwargs,
#    4384 ) -> Text:
# -> 4385     return gca().set_title(label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    4386
#    4387
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     198         title.update(default)
#     199         if fontdict is not None:
# --> 200             title.update(fontdict)
#     201         title._internal_update(kwargs)
#     202         return title
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/text.py in update(self, kwargs)
#     195         # docstring inherited
#     196         ret = []
# --> 197         kwargs = cbook.normalize_kwargs(kwargs, Text)
#     198         sentinel = object()  # bbox can be None, so use another sentinel.
#     199         # Update fontproperties first, as it has lowest priority.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in normalize_kwargs(kw, alias_mapping)
#    1785     ret = {}  # output dictionary
#    1786
# -> 1787     for k, v in kw.items():
#    1788         canonical = to_canonical.get(k, k)
#    1789         if canonical in canonical_to_seen:
#
# AttributeError: 'str' object has no attribute 'items'

# %%
# 9

frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'triangle'
winSize = 1024
specType = 'log'


sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(sig, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_298/4198998300.py in <cell line: 0>()
#       9
#      10
# ---> 11 sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      12 IPython.display.Audio(sig, rate=samplingRate)
#
# /tmp/ipykernel_298/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       7   plotAudio2(sig,samplingRate,waveType)
#       8
# ----> 9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#      10
#      11
#
# /tmp/ipykernel_298/3510600926.py in plotAudioFreqDomain(sig, sr, title, winSize, specType)
#       6     librosa.display.specshow(spec, y_axis=specType)
#       7     plt.colorbar(format='%+2.0f dB')
# ----> 8     plt.title({specType}, waveType)
#       9     plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    4383     **kwargs,
#    4384 ) -> Text:
# -> 4385     return gca().set_title(label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    4386
#    4387
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     198         title.update(default)
#     199         if fontdict is not None:
# --> 200             title.update(fontdict)
#     201         title._internal_update(kwargs)
#     202         return title
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/text.py in update(self, kwargs)
#     195         # docstring inherited
#     196         ret = []
# --> 197         kwargs = cbook.normalize_kwargs(kwargs, Text)
#     198         sentinel = object()  # bbox can be None, so use another sentinel.
#     199         # Update fontproperties first, as it has lowest priority.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in normalize_kwargs(kw, alias_mapping)
#    1785     ret = {}  # output dictionary
#    1786
# -> 1787     for k, v in kw.items():
#    1788         canonical = to_canonical.get(k, k)
#    1789         if canonical in canonical_to_seen:
#
# AttributeError: 'str' object has no attribute 'items'

# %%
# 10

frequency = 100
samplingRate = 44100
numHarmonics = 100
waveType = 'square'
winSize = 1024
specType = 'log'

sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
IPython.display.Audio(sig, rate=samplingRate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_298/2336940738.py in <cell line: 0>()
#       8 specType = 'log'
#       9
# ---> 10 sig = visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#      11 IPython.display.Audio(sig, rate=samplingRate)
#
# /tmp/ipykernel_298/2214864900.py in visualizeWaveforms(frequency, samplingRate, numHarmonics, winSize, waveType)
#       7   plotAudio2(sig,samplingRate,waveType)
#       8
# ----> 9   plotAudioFreqDomain(sig,samplingRate,numHarmonics,winSize,specType)
#      10
#      11
#
# /tmp/ipykernel_298/3510600926.py in plotAudioFreqDomain(sig, sr, title, winSize, specType)
#       6     librosa.display.specshow(spec, y_axis=specType)
#       7     plt.colorbar(format='%+2.0f dB')
# ----> 8     plt.title({specType}, waveType)
#       9     plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in title(label, fontdict, loc, pad, y, **kwargs)
#    4383     **kwargs,
#    4384 ) -> Text:
# -> 4385     return gca().set_title(label, fontdict=fontdict, loc=loc, pad=pad, y=y, **kwargs)
#    4386
#    4387
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in set_title(self, label, fontdict, loc, pad, y, **kwargs)
#     198         title.update(default)
#     199         if fontdict is not None:
# --> 200             title.update(fontdict)
#     201         title._internal_update(kwargs)
#     202         return title
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/text.py in update(self, kwargs)
#     195         # docstring inherited
#     196         ret = []
# --> 197         kwargs = cbook.normalize_kwargs(kwargs, Text)
#     198         sentinel = object()  # bbox can be None, so use another sentinel.
#     199         # Update fontproperties first, as it has lowest priority.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/cbook.py in normalize_kwargs(kw, alias_mapping)
#    1785     ret = {}  # output dictionary
#    1786
# -> 1787     for k, v in kw.items():
#    1788         canonical = to_canonical.get(k, k)
#    1789         if canonical in canonical_to_seen:
#
# AttributeError: 'str' object has no attribute 'items'
